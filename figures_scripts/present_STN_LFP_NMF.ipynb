# %%
import warnings
warnings.filterwarnings('ignore')

from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"
import os.path

from os import getcwd
import numpy as np
import pandas as pd
import h5py
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.io import savemat, loadmat
import math 
from scipy.fftpack import fft, ifft
from scipy.stats import zscore, f_oneway
#import samplerate
import multiprocessing as mp
from scipy.signal import resample
import random
import pyreadr
from scipy import stats
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import LeaveOneOut
from sklearn.metrics import r2_score
from mpl_toolkits.mplot3d import Axes3D
from sklearn import datasets
from sklearn.decomposition import NMF
import scipy.cluster.hierarchy as hac 
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans
import plotly.graph_objects as go
import plotly.express as px
import matplotlib.patches as patches

# %%
def zscore_bseline(input_mat):
    use_unit_z = np.zeros(input_mat.shape)
    for item in range(input_mat.shape[0]):
        use_unit = input_mat[item]
        unit_baseline = use_unit[0:1500]
        unit_baseline_mean = np.mean(unit_baseline)
        unit_baseline_std = np.std(unit_baseline)
        use_unit_z[item] = (use_unit - unit_baseline_mean)/unit_baseline_std
    return use_unit_z

# %%
use_cmap = sns.diverging_palette(220, 20, as_cmap=1, sep=125)

# %%
dbs_mat_band_hg.shape
# Out:
# (150, 5000)

# %%
dbs_chan_band = loadmat("processed_data/dbs_chan_1_200.mat")
dbs_mat_band_hg = dbs_chan_band['dbs_chan_1_200'].T
dbs_mat_band_hg = dbs_mat_band_hg[~np.all(dbs_mat_band_hg == 0, axis=1)]
#dbs_hg_info = dbs_chan_band['info']

fig, axs = plt.subplots(1, 1, figsize=(3, 3), dpi=200, constrained_layout=True)
sns.heatmap(zscore_bseline(dbs_mat_band_hg), cmap=use_cmap, cbar=1, 
            vmax=3, vmin=-3, ax=axs, yticklabels=False, xticklabels=500)

rect = patches.Rectangle((1500, 0), 1250, dbs_mat_band_hg.shape[0], 
                         edgecolor='none', facecolor='grey', alpha=0.3)
axs.add_patch(rect)

axs.set_xticks([500, 1500, 2500, 3500, 4500])
axs.set_xticklabels(["-1", "0", "1", "2", '3'], rotation=0, fontsize=15)
plt.title('Raw LFP', fontsize=15)
axs.set_ylabel('Channels', fontsize=15)
axs.set_ylabel('Time (s)', fontsize=15)

#cbar_ax = fig.add_axes([1, 0.2, 0.01, 0.6])
#cb = fig.colorbar(im1, cax=cbar_ax)
#cbar_ax.tick_params(labelsize=15)
#cb.outline.set_linewidth(0)

plt.show();

# %%
dbs_chan_band = loadmat("processed_data/dbs_chan_12_30.mat")
dbs_mat_band_hg = dbs_chan_band['dbs_chan_12_30'].T
dbs_mat_band_hg = dbs_mat_band_hg[~np.all(dbs_mat_band_hg == 0, axis=1)]
#dbs_hg_info = dbs_chan_band['info']

fig, axs = plt.subplots(1, 1, figsize=(3, 3), dpi=200, constrained_layout=True)
sns.heatmap(zscore_bseline(dbs_mat_band_hg), cmap=use_cmap, cbar=1, 
            vmax=3, vmin=-3, ax=axs, yticklabels=False, xticklabels=500)

rect = patches.Rectangle((1500, 0), 1250, dbs_mat_band_hg.shape[0], 
                         edgecolor='none', facecolor='grey', alpha=0.3)
axs.add_patch(rect)

axs.set_xticks([500, 1500, 2500, 3500, 4500])
axs.set_xticklabels(["-1", "0", "1", "2", '3'], rotation=0, fontsize=15)
plt.title('12-30Hz', fontsize=15)
axs.set_ylabel('Channels', fontsize=15)
axs.set_ylabel('Time (s)', fontsize=15)

#cbar_ax = fig.add_axes([1, 0.2, 0.01, 0.6])
#cb = fig.colorbar(im1, cax=cbar_ax)
#cbar_ax.tick_params(labelsize=15)
#cb.outline.set_linewidth(0)

plt.show();

# %%
dbs_chan_band = loadmat("processed_data/dbs_chan_30_70.mat")
dbs_mat_band_hg = dbs_chan_band['dbs_chan_30_70'].T
dbs_mat_band_hg = dbs_mat_band_hg[~np.all(dbs_mat_band_hg == 0, axis=1)]
#dbs_hg_info = dbs_chan_band['info']

fig, axs = plt.subplots(1, 1, figsize=(3, 3), dpi=200, constrained_layout=True)
sns.heatmap(zscore_bseline(dbs_mat_band_hg), cmap=use_cmap, cbar=1, 
            vmax=3, vmin=-3, ax=axs, yticklabels=False, xticklabels=500)

rect = patches.Rectangle((1500, 0), 1250, dbs_mat_band_hg.shape[0], 
                         edgecolor='none', facecolor='grey', alpha=0.3)
axs.add_patch(rect)

axs.set_xticks([500, 1500, 2500, 3500, 4500])
axs.set_xticklabels(["-1", "0", "1", "2", '3'], rotation=0, fontsize=15)
plt.title('30-70Hz', fontsize=15)
axs.set_ylabel('Channels', fontsize=15)
axs.set_ylabel('Time (s)', fontsize=15)

#cbar_ax = fig.add_axes([1, 0.2, 0.01, 0.6])
#cb = fig.colorbar(im1, cax=cbar_ax)
#cbar_ax.tick_params(labelsize=15)
#cb.outline.set_linewidth(0)

plt.show();

# %%
dbs_chan_band = loadmat("processed_data/dbs_chan_70_150.mat")
dbs_mat_band_hg = dbs_chan_band['dbs_chan_70_150'].T
dbs_mat_band_hg = dbs_mat_band_hg[~np.all(dbs_mat_band_hg == 0, axis=1)]
dbs_hg_info = dbs_chan_band['info']

# %%
dbs_mat_band_hg.shape
# Out:
# (150, 5000)

# %%
fig, axs = plt.subplots(1, 1, figsize=(3, 3), dpi=200, constrained_layout=True)
sns.heatmap(zscore_bseline(dbs_mat_band_hg), cmap=use_cmap, cbar=1, 
            vmax=3, vmin=-3, ax=axs, yticklabels=False, xticklabels=500)

rect = patches.Rectangle((1500, 0), 1250, dbs_mat_band_hg.shape[0], 
                         edgecolor='none', facecolor='grey', alpha=0.3)
axs.add_patch(rect)

axs.set_xticks([500, 1500, 2500, 3500, 4500])
axs.set_xticklabels(["-1", "0", "1", "2", '3'], rotation=0, fontsize=15)
plt.title('70-150Hz', fontsize=15)
axs.set_ylabel('Channels', fontsize=15)
axs.set_ylabel('Time (s)', fontsize=15)

plt.show();

# %%
axs.get_ylim()[1]
# Out:
# 2.6485054455337527

# %%
NMF_input = zscore_bseline(dbs_mat_band_hg)[:, :3000]

NMF_input = NMF_input - NMF_input.min()

model = NMF(n_components=4, init='random', random_state=0)
NMF_model = model.fit(NMF_input)


fig, axs = plt.subplots(1, 1, constrained_layout=True, figsize=(5, 3), dpi=200)
axs.patch.set_alpha(0)
fig.patch.set_alpha(0)

x_lab = np.linspace(-1.5, 1.5, 3000)

plt.plot(x_lab, NMF_model.components_[0], label='C1', lw=0.5)
plt.plot(x_lab, NMF_model.components_[1], label='C2', lw=0.5)
plt.plot(x_lab, NMF_model.components_[2], label='C3', lw=0.5)
plt.plot(x_lab, NMF_model.components_[3], label='C4', lw=0.5)
#plt.scatter(x=x_lab, y=NMF_model.components_[4], label='C5')
plt.title('70-150Hz', fontsize=15)
rect = patches.Rectangle((0, 0), 1.25, axs.get_ylim()[1], 
                         edgecolor='none', facecolor='grey', alpha=0.3)
axs.add_patch(rect)
plt.legend(frameon=0)
plt.show();

# %%
dbs_chan_band = loadmat("processed_data/dbs_chan_1_200.mat")
dbs_mat_band = dbs_chan_band['dbs_chan_1_200'].T
dbs_mat_band = dbs_mat_band[~np.all(dbs_mat_band == 0, axis=1)]
dbs_info = dbs_chan_band['info']

# %%
fig, axs = plt.subplots(1, 1, figsize=(6, 5), dpi=200, constrained_layout=True)
sns.heatmap(zscore_bseline(dbs_mat_band), cmap=use_cmap, cbar=False, 
            vmax=3, vmin=-3, ax=axs, yticklabels=False, xticklabels=500)

rect = patches.Rectangle((1500, 0), 1250, dbs_mat_band.shape[0], 
                         edgecolor='none', facecolor='grey', alpha=0.3)
axs.add_patch(rect)

axs.set_xticks([500, 1500, 2500, 3500, 4500])
axs.set_xticklabels(["-1s", "0s", "1s", "2s", '3s'], rotation=45, fontsize=15)
plt.title('0-200Hz', fontsize=15)
plt.show();

# %%
NMF_input = zscore_bseline(dbs_mat_band)[:, :3000]

NMF_input = NMF_input - NMF_input.min()

model = NMF(n_components=4, init='random', random_state=0)
NMF_model = model.fit(NMF_input)


fig, axs = plt.subplots(1, 1, constrained_layout=True, figsize=(5, 3), dpi=200)
axs.patch.set_alpha(0)
fig.patch.set_alpha(0)

x_lab = np.linspace(-1.5, 1.5, 3000)

plt.plot(x_lab, NMF_model.components_[0], label='C1', lw=0.5)
plt.plot(x_lab, NMF_model.components_[1], label='C2', lw=0.5)
plt.plot(x_lab, NMF_model.components_[2], label='C3', lw=0.5)
plt.plot(x_lab, NMF_model.components_[3], label='C4', lw=0.5)
#plt.scatter(x=x_lab, y=NMF_model.components_[4], label='C5')
plt.title('0-200Hz', fontsize=15)
rect = patches.Rectangle((0, 0), 1.25, axs.get_ylim()[1], 
                         edgecolor='none', facecolor='grey', alpha=0.3)
axs.add_patch(rect)
plt.legend(frameon=0)
plt.show();

# %%
NMF_input = zscore_bseline(dbs_mat_band)[:, :3000]

NMF_input = NMF_input - NMF_input.min()

model = NMF(n_components=5, init='random', random_state=0)
NMF_model = model.fit(NMF_input)


fig, axs = plt.subplots(1, 1, constrained_layout=True, figsize=(5, 3), dpi=200)
axs.patch.set_alpha(0)
fig.patch.set_alpha(0)

x_lab = np.linspace(-1.5, 1.5, 3000)

plt.scatter(x=x_lab, y=NMF_model.components_[0], label='C1')
plt.scatter(x=x_lab, y=NMF_model.components_[1], label='C2')
plt.scatter(x=x_lab, y=NMF_model.components_[2], label='C3')
plt.scatter(x=x_lab, y=NMF_model.components_[3], label='C4')
plt.scatter(x=x_lab, y=NMF_model.components_[4], label='C5')

plt.legend()
plt.show();

# %%
dbs_chan_band = loadmat("processed_data/dbs_chan_12_30.mat")
dbs_mat_band_beta = dbs_chan_band['dbs_chan_12_30'].T
dbs_mat_band_beta = dbs_mat_band_beta[~np.all(dbs_mat_band_beta == 0, axis=1)]
dbs_beta_info = dbs_chan_band['info']

# %%
fig, axs = plt.subplots(1, 1, figsize=(6, 5), dpi=200, constrained_layout=True)
sns.heatmap(zscore_bseline(dbs_mat_band_beta), cmap=use_cmap, cbar=False, 
            vmax=3, vmin=-3, ax=axs, yticklabels=False, xticklabels=500)

rect = patches.Rectangle((1500, 0), 1250, dbs_mat_band_beta.shape[0], 
                         edgecolor='none', facecolor='grey', alpha=0.3)
axs.add_patch(rect)

axs.set_xticks([500, 1500, 2500, 3500, 4500])
axs.set_xticklabels(["-1s", "0s", "1s", "2s", '3s'], rotation=45, fontsize=15)
plt.title('12-30Hz', fontsize=15)
plt.show();

# %%
NMF_input = zscore_bseline(dbs_mat_band_beta)[:, :3000]

NMF_input = NMF_input - NMF_input.min()

model = NMF(n_components=4, init='random', random_state=0)
NMF_model = model.fit(NMF_input)


fig, axs = plt.subplots(1, 1, constrained_layout=True, figsize=(5, 3), dpi=200)
axs.patch.set_alpha(0)
fig.patch.set_alpha(0)

x_lab = np.linspace(-1.5, 1.5, 3000)

plt.plot(x_lab, NMF_model.components_[0], label='C1', lw=0.5)
plt.plot(x_lab, NMF_model.components_[1], label='C2', lw=0.5)
plt.plot(x_lab, NMF_model.components_[2], label='C3', lw=0.5)
plt.plot(x_lab, NMF_model.components_[3], label='C4', lw=0.5)
#plt.scatter(x=x_lab, y=NMF_model.components_[4], label='C5')
plt.title('12-30Hz', fontsize=15)
rect = patches.Rectangle((0, 0), 1.25, axs.get_ylim()[1], 
                         edgecolor='none', facecolor='grey', alpha=0.3)
axs.add_patch(rect)
plt.legend(frameon=0)
plt.show();

# %%
NMF_input = zscore_bseline(dbs_mat_band_beta)[:, :3000]

NMF_input = NMF_input - NMF_input.min()

model = NMF(n_components=5, init='random', random_state=0)
NMF_model = model.fit(NMF_input)


fig, axs = plt.subplots(1, 1, constrained_layout=True, figsize=(5, 3), dpi=200)
axs.patch.set_alpha(0)
fig.patch.set_alpha(0)

x_lab = np.linspace(-1.5, 1.5, 3000)

plt.scatter(x=x_lab, y=NMF_model.components_[0], label='C1')
plt.scatter(x=x_lab, y=NMF_model.components_[1], label='C2')
plt.scatter(x=x_lab, y=NMF_model.components_[2], label='C3')
plt.scatter(x=x_lab, y=NMF_model.components_[3], label='C4')
plt.scatter(x=x_lab, y=NMF_model.components_[4], label='C5')

plt.legend()
plt.show();

# %%
dbs_chan_band = loadmat("processed_data/dbs_chan_30_70.mat")
dbs_mat_band_lg = dbs_chan_band['dbs_chan_30_70'].T
dbs_mat_band_lg = dbs_mat_band_lg[~np.all(dbs_mat_band_lg == 0, axis=1)]
dbs_lg_info = dbs_chan_band['info']

# %%
fig, axs = plt.subplots(1, 1, figsize=(6, 5), dpi=200, constrained_layout=True)
sns.heatmap(zscore_bseline(dbs_mat_band_lg), cmap=use_cmap, cbar=False, 
            vmax=3, vmin=-3, ax=axs, yticklabels=False, xticklabels=500)

rect = patches.Rectangle((1500, 0), 1250, dbs_mat_band_lg.shape[0], 
                         edgecolor='none', facecolor='grey', alpha=0.3)
axs.add_patch(rect)

axs.set_xticks([500, 1500, 2500, 3500, 4500])
axs.set_xticklabels(["-1s", "0s", "1s", "2s", '3s'], rotation=45, fontsize=15)
plt.title('30-70Hz', fontsize=15)
plt.show();

# %%
NMF_input = zscore_bseline(dbs_mat_band_lg)[:, :3000]

NMF_input = NMF_input - NMF_input.min()

model = NMF(n_components=4, init='random', random_state=0)
NMF_model = model.fit(NMF_input)


fig, axs = plt.subplots(1, 1, constrained_layout=True, figsize=(5, 3), dpi=200)
axs.patch.set_alpha(0)
fig.patch.set_alpha(0)

x_lab = np.linspace(-1.5, 1.5, 3000)

plt.plot(x_lab, NMF_model.components_[0], label='C1', lw=0.5)
plt.plot(x_lab, NMF_model.components_[1], label='C2', lw=0.5)
plt.plot(x_lab, NMF_model.components_[2], label='C3', lw=0.5)
plt.plot(x_lab, NMF_model.components_[3], label='C4', lw=0.5)
#plt.scatter(x=x_lab, y=NMF_model.components_[4], label='C5')
plt.title('30-70Hz', fontsize=15)
rect = patches.Rectangle((0, 0), 1.25, axs.get_ylim()[1], 
                         edgecolor='none', facecolor='grey', alpha=0.3)
axs.add_patch(rect)
plt.legend(frameon=0)
plt.show();

# %%
NMF_input = zscore_bseline(dbs_mat_band_lg)[:, :3000]

NMF_input = NMF_input - NMF_input.min()

model = NMF(n_components=5, init='random', random_state=0)
NMF_model = model.fit(NMF_input)


fig, axs = plt.subplots(1, 1, constrained_layout=True, figsize=(5, 3), dpi=200)
axs.patch.set_alpha(0)
fig.patch.set_alpha(0)

x_lab = np.linspace(-1.5, 1.5, 3000)

plt.scatter(x=x_lab, y=NMF_model.components_[0], label='C1')
plt.scatter(x=x_lab, y=NMF_model.components_[1], label='C2')
plt.scatter(x=x_lab, y=NMF_model.components_[2], label='C3')
plt.scatter(x=x_lab, y=NMF_model.components_[3], label='C4')
plt.scatter(x=x_lab, y=NMF_model.components_[4], label='C5')

plt.legend()
plt.show();
